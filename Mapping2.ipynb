# %%
# !pip install osmnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import osmnx as ox
import pandas as pd

# %%
place = "Bangalore, India"

# %%
tags2 = {"amenity":"atm"}

# %%
df2 = ox.geometries_from_place(place, tags2)
# Out:
# <ipython-input-6-1dcb2d19014f>:1: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release.
#   df2 = ox.geometries_from_place(place, tags2)

# %%
list(atm_bangalore.columns.values)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['amenity',
#  'brand',
#  'brand:wikidata',
#  'name',
#  'name:kn',
#  'operator',
#  'operator:wikidata',
#  'short_name',
#  'geometry',
#  'addr:street',
#  'opening_hours',
#  'check_date',
#  'branch',
#  'brand:en',
#  'brand:hi',
#  'brand:kn',
#  'brand:pa',
#  'brand:pnb',
#  'brand:ur',
#  'brand:wikipedia',
#  'brand:wikipedia:pa',
#  'name:en',
#  'name:hi',
#  'name:pa',
#  'name:pnb',
#  'name:ur',
#  'addr:city',
#  'addr:postcode',
#  'atm',
#  'cost',
#  'wheelchair',
#  'fee',
#  'currency:INR',
#  'drive_through',
#  'operator:wikipedia',
#  'cash_in',
#  'level',
#  'network',
#  'source',
# ...

# %%
atm_bangalore = pd.DataFrame(df2)

# %%
station1 = station.loc[station['operator'] == "BMRCL"]

# %%
print(station1)

# %%
school_satara.to_csv("school_satara.csv")
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()

# %%
station1 = station1.loc[station1['disused'] != "yes"]

# %%
station1 = station1.loc[station1['disused:railway'] != "station"]

# %%
station1.to_csv("stations1.csv")

# %%
atm_bangalore.to_csv("atm_bangalore.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# ...

# %%
station_sel = station1.sample(n=10)

# %%
print(station_sel)

# %%
station_sel.to_csv("selected_stations.csv")

# %%
tags3 = {"amenity" : "hospital"}

# %%
hospital = ox.geometries_from_place(place, tags3)

# %%
hospital.shape

# %%
hospital = pd.DataFrame(hospital)

# %%
hospital.to_csv("hospital_new.csv")

# %%
hospital_gdf = gp.GeoDataFrame(hospital, crs="EPSG:4326", geometry=station_sel.geometry)

# %%
hospital_gdf.head()

# %%
list(hospital_df.columns.values)

# %%
hospital_df.to_csv("hospital.csv")

# %%
tags4 = {"amenity" : "restaurant"}

# %%
#import osmnx as ox

restr = ox.geometries_from_place(place, tags4)

# %%
restr.shape

# %%
#import pandas as pd

restr_df = pd.DataFrame(restr)

# %%
restr_df.to_csv("restr_new.csv")

# %%
rest_gdf = gp.GeoDataFrame(restr_df, crs="EPSG:4326", geometry=restr_df.geometry)

# %%
# !pip install arcpy=2.9 -c esri

# %%
#!pip install geopandas

type(station_sel)

# %%
import geopandas as gp

# %%
station_gdf = gp.GeoDataFrame(station_sel, crs="EPSG:4326", geometry=station_sel.geometry)

# %%
type(station_gdf)

# %%
station_gdf = station_gdf.to_crs({'init': 'epsg:32643'})

# %%
station_gdf500 = station_gdf.buffer(500)

# %%
import matplotlib.pyplot as plt

# %%
station_gdf500.plot()

# %%
tags6 = {"boundary": "administrative"}

# %%
bg = ox.geometries_from_place(place, tags6)

# %%
bg.to_csv("bg.csv")

# %%
# !pip install PyShp

# %%
import shapefile

# %%
myshp = open("BBMP2011.shp", "rb")

# %%
mydbf = open("BBMP2011.dbf", "rb")

# %%
print(mydbf)

# %%
bg = shapefile.Reader(shp = myshp, dbf = mydbf)

# %%
sf.plot()

# %%
bg_gdf = gp.GeoDataFrame(sf, crs="EPSG:4326", geometry=sf.geometry)

# %%
plt.figure()
for shape in bg.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()

# %%
fig, ax1 = plt.subplots()

# %%
for shape in bg.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    bgplot = plt.plot(x,y)

# %%
station_gdf500.plot()

# %%
fig, ax = plt.subplots(figsize = (10,10))
station_gdf500.plot(ax=ax, alpha = 0.4, color = 'red')
rest_gdf.plot(ax=ax, alpha = 0.2, color = 'blue')
for shape in bg.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    bgplot = plt.plot(x,y)
plt.show()

# %%
rest_gdf.plot()

# %%
rest_gdf = rest_gdf.to_crs({'init': 'epsg:32643'})
